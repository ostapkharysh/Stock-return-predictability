# %%
from pyft.pyft import FT

# %%
ft = FT("59cbaf20e3e06d3565778e7b742c3b5d2f514556879456ebfc8ab2c2")

# %%
updated_content = ft.get_content_notifications(updated_since="2018-07-22")

# %%
updated_content
# Out:
# {'links': [{'href': 'https://api.ft.com/content/notifications?page=MjAxODA3MjMxNTQ4MzUuNzYxIzAjdXBwLXByb2QtZGVsaXZlcnktZXU%3D&since=2018-07-23T15%3A48%3A35.761Z',
#    'rel': 'next'}],
#  'notifications': [{'apiUrl': 'https://api.ft.com/content/60e50482-8b6d-11e8-bf9e-8771d5404543',
#    'id': 'http://www.ft.com/thing/60e50482-8b6d-11e8-bf9e-8771d5404543',
#    'type': 'http://www.ft.com/thing/ThingChangeType/UPDATE'},
#   {'apiUrl': 'https://api.ft.com/content/b2b10d3c-8a6f-11e8-bf9e-8771d5404543',
#    'id': 'http://www.ft.com/thing/b2b10d3c-8a6f-11e8-bf9e-8771d5404543',
#    'type': 'http://www.ft.com/thing/ThingChangeType/UPDATE'},
#   {'apiUrl': 'https://api.ft.com/content/8db6d408-8bff-11e8-affd-da9960227309',
#    'id': 'http://www.ft.com/thing/8db6d408-8bff-11e8-affd-da9960227309',
#    'type': 'http://www.ft.com/thing/ThingChangeType/UPDATE'},
#   {'apiUrl': 'https://api.ft.com/content/b6ab0f4a-8cc8-11e8-b639-7680cedcc421',
# ...
