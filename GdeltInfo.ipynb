'20180715194500', '20180715200000', '20180715201500', '20180715203000', '20180715204500', '20180715210000', '20180715211500', '20180715213000', '20180715214500', '20180715220000', '20180715221500', '20180715223000', '20180715224500', '20180715230000', '20180715231500', '20180715233000', '20180715234500', '20180716000000', '20180716004500', '20180716010000', '20180716013000', '20180716014500', '20180716020000', '20180716021500', '20180716023000', '20180810010000', '20180810011500', '20180821181500', '20180821183000', '20180821184500', '20180821190000', '20180821191500', '20180821193000', '20180821194500', '20180821200000', '20181213114500', '20181213121500', '20181213123000']

# %%
len(miss_to_download)
# Out:
# 2019

# %% [markdown]
# ### GDELT DATA from 2016 - 2018 years

# %%
missing_days = len(miss_to_download)*15/60/24
"Missing time period in days: {}".format(round(missing_days, 2))
# Out:
# 'Missing time period in days: 21.03'

# %%
"Percentage of absent data: {}%".format(round(missing_days / 3 / 365  * 100, 2))
# Out:
# 'Percentage of absent data: 1.92%'

# %%
import matplotlib.pyplot as plt
import matplotlib
# necessary for the plot to appear in a Jupyter
# %matplotlib inline
# Control the default size of figures in this Jupyter 
# %pylab inline
matplotlib.rcParams['figure.figsize'] = (20.0, 10.0)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/ostapkharysh/.local/lib/python3.5/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['select', 'table']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
START  = '20160101000000'
FINISH = '20160201000000'

# %%
#SQLALCHEMY
from sqlalchemy import create_engine
from sqlalchemy import inspect, select, MetaData, and_
import datetime
import pandas as pd

db_uri = 'postgresql://ostap:12345@localhost:5432/goog'
engine = create_engine(db_uri)
conn = engine.connect()

inspector = inspect(engine)

# Get table information

meta = MetaData(engine,reflect=True)
table = meta.tables['news']

#print(inspector.get_table_names())
#print(inspector.get_columns('news'))

select_st = select([table.c.DATE, table.c.TONE, table.c.DOCUMENTIDENTIFIER, table.c.SOURCECOMMONNAME, table.c.GCAM]).where(and_(table.c.DATE < FINISH , table.c.DATE > START))

res = conn.execute(select_st).fetchall()


news = dict()
news['date'] = [datetime.datetime.strptime(el[0], '%Y%m%d%H%M%S') for el in res if '.' not in el[0]]

sents = [el[1] for el in res if '.' not in el[0]]


conn.close()

sent = [x.split(',') for x in sents]

news['tone'] = [float(el[0]) for el in sent]
news['positive'] = [float(el[1]) for el in sent]
news['negative'] = [float(el[2]) for el in sent]
news['polarity'] = [float(el[3]) for el in sent]
news['activ_den'] = [float(el[4]) for el in sent]
news['self_den'] = [float(el[5]) for el in sent]

news['source'] = [el[2] for el in res if '.' not in el[0]]
news['agency'] = [el[3] for el in res if '.' not in el[0]]
news['words'] = [el[4] for el in res if '.' not in el[0]]

del res

TONE = pd.DataFrame.from_dict(news)




# TONE_15_M = pd.DataFrame({'date': [], 'tone': [], 'source': [],  'agency': [], 'words': []})

# for idx, el in enumerate(list(set(TONE.date))):
#     one_p_tones = TONE.loc[TONE.date==el].tone.values
#     one_p_words = TONE.loc[TONE.date==el].words.values
#     one_p_source = TONE.loc[TONE.date==el].source.values
#     one_p_agency = TONE.loc[TONE.date==el].agency.values
#     TONE_15_M.loc[idx] = pd.Series({"date": el, "tone": one_p_tones, "source": one_p_source , 'agency': one_p_agency, "words": one_p_words})

# TONE_15_M = TONE_15_M.sort_values(by=['date'])
# TONE_15_M.head()
# Out:
# /home/ostapkharysh/.local/lib/python3.5/site-packages/ipykernel_launcher.py:15: SADeprecationWarning: reflect=True is deprecate; please use the reflect() method.
#   from ipykernel import kernelapp as app

# %%
TONE = TONE.sort_values(by=['date'])
TONE = TONE[['date', 'tone', 'positive', 'negative', 'polarity', 'activ_den', 'self_den', 'source', 'agency', 'words']]
TONE = TONE.reset_index(drop=True)

# %%
TONE.head()
# Out:
#                  date      tone  positive  negative  polarity  activ_den  \
# 0 2016-01-01 00:15:00 -1.503165  2.215190  3.718354  5.933544  22.468354
# 1 2016-01-01 00:15:00 -1.758014  2.068252  3.826267  5.894519  24.819028
# 2 2016-01-01 00:15:00 -4.637097  1.209677  5.846774  7.056452  22.580645
# 3 2016-01-01 00:15:00 -3.191489  1.773050  4.964539  6.737589  19.858156
# 4 2016-01-01 00:15:00  1.908397  2.671756  0.763359  3.435115  20.992366
#
#    self_den                                             source  \
# 0  0.474684  http://fox17.com/news/nation-world/us-stocks-e...
# 1  0.310238  http://www.nzherald.co.nz/opinion/news/article...
# 2  0.000000  http://www.kionrightnow.com/life/money/dow-clo...
# 3  1.063830  http://www.gizmodo.co.uk/2015/12/microsoft-got...
# 4  0.000000  http://www.mlive.com/news/kalamazoo/index.ssf/...
#
#              agency                                              words
# 0         fox17.com  wc:1138,c1.2:17,c12.1:74,c12.10:115,c12.12:52,...
# 1    nzherald.co.nz  wc:894,c1.2:4,c1.3:2,c12.1:74,c12.10:112,c12.1...
# 2  kionrightnow.com  wc:437,c1.2:2,c12.1:26,c12.10:46,c12.12:21,c12...
# 3     gizmodo.co.uk  wc:250,c1.3:3,c12.1:10,c12.10:12,c12.12:2,c12....
# 4         mlive.com  wc:230,c1.1:2,c12.1:6,c12.10:10,c12.12:1,c12.1...

# %%
len(TONE)
# Out:
# 170975

# %%
TONE.corr()
# Out:
#                tone  positive  negative  polarity  activ_den  self_den
# tone       1.000000  0.669095 -0.870019 -0.396715  -0.105726  0.157620
# positive   0.669095  1.000000 -0.215725  0.416753  -0.031091  0.142621
# negative  -0.870019 -0.215725  1.000000  0.797712   0.118288 -0.112482
# polarity  -0.396715  0.416753  0.797712  1.000000   0.090918 -0.016634
# activ_den -0.105726 -0.031091  0.118288  0.090918   1.000000  0.246616
# self_den   0.157620  0.142621 -0.112482 -0.016634   0.246616  1.000000

# %% [markdown]
# ## Price Tone Correlation

# %%
intraday = pd.DataFrame(columns=['date', 'price'])

with open("additional_data/202_googl.txt", "r") as stock:
    for line in stock:
        el = line.split(" ")[0]+" "+ line.split(" ")[1]
        data = datetime.datetime.strptime(line.split(" ")[0]+" "+ line.split(" ")[1], '%Y-%m-%d %H:%M:%S')
        intraday = intraday.append({'date': data, 'price': float(line.split(" ")[-1].strip())}, ignore_index = True)

# %%
intraday.head()
# Out:
#                  date    price
# 0 2016-01-04 09:45:00  752.810
# 1 2016-01-04 09:46:00  752.640
# 2 2016-01-04 09:47:00  752.638
# 3 2016-01-04 09:48:00  754.500
# 4 2016-01-04 09:49:00  753.860

# %%
period_df = intraday[(intraday['date'] > START ) & (intraday['date'] < FINISH)]  #'2016-01-31 23:45:00'

# %%
period_df['date'] = pd.to_datetime(period_df['date'])
# Out:
# /home/ostapkharysh/.local/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
start = datetime.datetime.strptime(START, '%Y%m%d%H%M%S') #2016-02-01
finish = datetime.datetime.strptime(FINISH, '%Y%m%d%H%M%S')

step = datetime.timedelta(minutes=15)
t = start

time = list()
while t < finish:
    time.append(t)
    t+=step

# %%
period_df = period_df[pd.to_datetime(period_df['date'].values).minute % 15 == 0]
period_df = period_df.reset_index(drop=True)

# %%
lack_p = set(time) - set(period_df['date'])

for el in lack_p:
    period_df = period_df.append({'date': el, 'price': np.nan}, ignore_index = True)
    
lack_t = set(time) - set(TONE['date'])
for el in lack_t:
    TONE = TONE.append({'date': el, 'tone': np.nan, 'positive': np.nan, 
                                   'negative': np.nan, 'polarity' : np.nan, 
                                    'activ_den': np.nan, 
                                    'self_den' : np.nan}, ignore_index = True)

# %%
period_df = period_df.sort_values(by=['date'])
TONE = TONE.sort_values(by=['date'])

period_df = period_df.reset_index(drop=True)
TONE = TONE.reset_index(drop=True)

# %%
TONE['price']=TONE[['date']].merge(period_df,how='left').price

# %%
TONE.head()
# Out:
#                  date      tone  positive  negative  polarity  activ_den  \
# 0 2016-01-01 00:00:00       NaN       NaN       NaN       NaN        NaN
# 1 2016-01-01 00:15:00 -1.503165  2.215190  3.718354  5.933544  22.468354
# 2 2016-01-01 00:15:00 -0.239808  3.357314  3.597122  6.954436  21.902478
# 3 2016-01-01 00:15:00 -2.764977  2.534562  5.299539  7.834101  21.006144
# 4 2016-01-01 00:15:00  6.430155  7.982262  1.552106  9.534368  22.912047
#
#    self_den                                             source  \
# 0       NaN                                                NaN
# 1  0.474684  http://fox17.com/news/nation-world/us-stocks-e...
# 2  3.517186  http://www.nwitimes.com/business/local/gadgets...
# 3  1.036866  http://www.theunitedvoiceofamerica.com/mccain-...
# 4  1.626016        http://comicsalliance.com/tags/braden-lamb/
#
#                         agency  \
# 0                          NaN
# 1                    fox17.com
# 2                 nwitimes.com
# 3  theunitedvoiceofamerica.com
# 4           comicsalliance.com
#
#                                                words  price
# 0                                                NaN    NaN
# 1  wc:1138,c1.2:17,c12.1:74,c12.10:115,c12.12:52,...    NaN
# 2  wc:1079,c12.1:113,c12.10:134,c12.12:36,c12.13:...    NaN
# 3  wc:2341,c1.1:1,c1.3:4,c1.4:5,c12.1:191,c12.10:...    NaN
# 4  wc:1193,c1.1:2,c1.4:2,c12.1:101,c12.10:121,c12...    NaN

# %%
matplotlib.rcParams['figure.figsize'] = (10.0, 5.0)

corr = TONE.corr(method ="pearson")
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(TONE[['tone', 'positive', 'negative', 'polarity', 'activ_den', 'self_den', 'price']].columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(TONE[['tone', 'positive', 'negative', 'polarity', 'activ_den', 'self_den', 'price']].columns)
ax.set_yticklabels(TONE[['tone', 'positive', 'negative', 'polarity', 'activ_den', 'self_den', 'price']].columns)
plt.show()

# %%
TONE.corr()
# Out:
#                tone  positive  negative  polarity  activ_den  self_den  \
# tone       1.000000  0.669095 -0.870019 -0.396715  -0.105726  0.157620
# positive   0.669095  1.000000 -0.215725  0.416753  -0.031091  0.142621
# negative  -0.870019 -0.215725  1.000000  0.797712   0.118288 -0.112482
# polarity  -0.396715  0.416753  0.797712  1.000000   0.090918 -0.016634
# activ_den -0.105726 -0.031091  0.118288  0.090918   1.000000  0.246616
# self_den   0.157620  0.142621 -0.112482 -0.016634   0.246616  1.000000
# price     -0.004974 -0.019422 -0.006937 -0.018891   0.026597 -0.018827
#
#               price
# tone      -0.004974
# positive  -0.019422
# negative  -0.006937
# polarity  -0.018891
# activ_den  0.026597
# self_den  -0.018827
# price      1.000000

# %%
from collections import Counter
agency = dict(Counter(TONE.agency))

# %%
list(agency)[:10]
# Out:
# [nan,
#  'gas2.org',
#  'singaporeinformer.com',
#  'zimeye.net',
#  'loudountimes.com',
#  'talkingpointsmemo.com',
#  'echoexaminer.com',
#  'eastwoodadvertiser.co.uk',
#  'atlanticcouncil.org',
#  'bunburymail.com.au']

# %%
agencies_lst = list(agency.items())

# %%
agencies_lst
# Out:
# [(nan, 32),
#  ('gas2.org', 8),
#  ('singaporeinformer.com', 1),
#  ('zimeye.net', 1),
#  ('loudountimes.com', 1),
#  ('talkingpointsmemo.com', 9),
#  ('echoexaminer.com', 2),
#  ('eastwoodadvertiser.co.uk', 4),
#  ('atlanticcouncil.org', 2),
#  ('bunburymail.com.au', 29),
#  ('ajc.com', 78),
#  ('distressedmullet.com', 1),
#  ('current.org', 6),
#  ('ksdk.com', 25),
#  ('filmibeat.com', 4),
#  ('insidehalton.com', 82),
#  ('residententertainment.com', 1),
#  ('premierchristianradio.com', 4),
#  ('thetablet.co.uk', 2),
#  ('illinoisstate.edu', 2),
#  ('kxly.com', 48),
#  ('arbroathherald.co.uk', 1),
#  ('jetnation.com', 4),
#  ('bellingencourier.com.au', 25),
#  ('nseavoice.com', 3),
#  ('sanjuanjournal.com', 1),
#  ('practicalecommerce.com', 1),
#  ('northernvatimes.com', 8),
#  ('dnasyndication.com', 3),
#  ('bloodyelbow.com', 11),
#  ('benzinga.com', 333),
#  ('insideireland.ie', 1),
#  ('publicopiniononline.com', 14),
#  ('safc.com', 1),
#  ('skydancingblog.com', 2),
#  ('captees.com', 1),
#  ('stellingwerf.nl', 1),
#  ('desertdispatch.com', 1),
#  ('inquisitiveeater.com', 1),
#  ('conservatives.com', 1),
#  ('globalissues.org', 1),
#  ('jambands.com', 2),
#  ('mendocinobeacon.com', 1),
#  ('mmajunkie.com', 4),
#  ('vator.tv', 32),
#  ('southernweekly.com.au', 26),
#  ('af.mil', 2),
#  ('government.leadership.ng', 2),
#  ('kcwy13.com', 1),
#  ('financialspots.com', 15),
#  ('psiimpact.com', 1),
#  ('runningmagazine.ca', 2),
#  ('cbs46.com', 25),
#  ('whtimes.co.uk', 2),
#  ('totalpackers.com', 1),
#  ('parade.com', 9),
#  ('kspr.com', 42),
#  ('sandiegocan.org', 1),
#  ('uatoday.tv', 8),
#  ('qctimes.com', 111),
#  ('geeknewscentral.com', 1),
#  ('theclimategroup.org', 1),
#  ('newvision.co.ug', 14),
#  ('dailyrecord.com', 12),
#  ('kfbb.com', 32),
#  ('cdapress.com', 13),
#  ('citybeat.com', 4),
#  ('courierpress.com', 14),
#  ('telegraph.co.uk', 223),
#  ('scroll.in', 15),
#  ('wyff4.com', 13),
#  ('just-auto.com', 14),
#  ('brooklynrail.org', 3),
#  ('dailymirror.lk', 4),
#  ('afarmgirlsdabbles.com', 1),
#  ('lakegenevanews.net', 1),
#  ('parenting.com', 6),
#  ('newsandsentinel.com', 16),
#  ('wfmj.com', 21),
#  ('delta-optimist.com', 168),
#  ('radiotoday.com.au', 6),
#  ('scpr.org', 20),
#  ('blufftonicon.com', 3),
#  ('pbfingers.com', 1),
#  ('missmalini.com', 1),
#  ('galvnews.com', 5),
#  ('caradvice.com.au', 8),
#  ('cfra.com', 5),
#  ('primenews.com.bd', 11),
#  ('histalk2.com', 1),
#  ('defenseone.com', 7),
#  ('hidesertstar.com', 1),
#  ('arabianbusiness.com', 13),
#  ('richardsilverstein.com', 2),
#  ('middevongazette.co.uk', 2),
#  ('mindef.gov.sg', 1),
#  ('wyso.org', 1),
#  ('messengernewspapers.co.uk', 15),
#  ('epworthbells.co.uk', 4),
#  ('techly.com.au', 19),
#  ('uark.edu', 2),
#  ('electronicsweekly.com', 8),
#  ('fox34.com', 21),
#  ('wkbn.com', 8),
#  ('reddirtreport.com', 2),
#  ('visionkl.com', 1),
#  ('domainnamewire.com', 1),
#  ('bilan.ch', 1),
#  ('hq02.com', 1),
#  ('mix961.com', 9),
#  ('healthcareasia.org', 1),
#  ('starherald.com', 22),
#  ('housepricecrash.co.uk', 1),
#  ('courier-journal.com', 27),
#  ('christiantimes.com', 1),
#  ('ydr.com', 22),
#  ('press-citizen.com', 12),
#  ('fasterskier.com', 1),
#  ('eastday.com', 1),
#  ('e-forologia.gr', 1),
#  ('technewsworld.com', 83),
#  ('sfsignal.com', 5),
#  ('afrika.no', 1),
#  ('wauchopegazette.com.au', 25),
#  ('vcstar.com', 28),
#  ('wsfa.com', 56),
#  ('commercialappeal.com', 10),
#  ('andhrawishesh.com', 4),
#  ('bleacherreport.com', 15),
#  ('almanar.com.lb', 14),
#  ('mwnation.com', 1),
#  ('prague.tv', 5),
#  ('hutchnews.com', 242),
#  ('retailtimes.co.uk', 2),
#  ('nbcnewyork.com', 9),
#  ('hpcwire.com', 5),
#  ('bannergraphic.com', 3),
#  ('ncronline.org', 6),
#  ('folkestoneherald.co.uk', 2),
#  ('ottawaradio.net', 30),
#  ('beat.com.au', 2),
#  ('ncadvertiser.com', 2),
#  ('npr.org', 39),
#  ('mobilecommercepress.com', 26),
#  ('thenonprofittimes.com', 1),
#  ('soundonsound.com', 7),
#  ('inverse.com', 10),
#  ('propakistani.pk', 25),
#  ('copblock.org', 8),
#  ('franchiseherald.com', 3),
#  ('honolulumagazine.com', 12),
#  ('investorguide.com', 5),
#  ('thereelnetwork.net', 2),
#  ('evwind.es', 5),
#  ('vagazette.com', 10),
#  ('sophos.com', 16),
#  ('scsuntimes.com', 10),
#  ('foodthatsings.com', 1),
#  ('thedailysheeple.com', 12),
#  ('zdistrict.com', 3),
#  ('worldufophotosandnews.org', 1),
#  ('popherald.com', 56),
#  ('channellife.co.nz', 3),
#  ('wagmtv.com', 3),
#  ('mamamia.com.au', 49),
#  ('techreport.com', 18),
#  ('publicradioeast.org', 1),
#  ('hillnow.com', 1),
#  ('crescent-news.com', 5),
#  ('rdm.co.za', 2),
#  ('dol.gov', 1),
#  ('farandulife.com', 31),
#  ('blueridgenow.com', 41),
#  ('payvand.com', 1),
#  ('am980.ca', 2),
#  ('stud-jur.dk', 1),
#  ('waterstechnology.com', 3),
#  ('thevitalounge.net', 2),
#  ('rockmnation.com', 1),
#  ('haberartiturk.com', 1),
#  ('techzim.co.zw', 6),
#  ('automotive-business-review.com', 5),
#  ('enca.com', 35),
#  ('therecord.com', 84),
#  ('artandeducation.net', 4),
#  ('foodonline.com', 1),
#  ('mindanaoan.com', 1),
#  ('diynatural.com', 1),
#  ('japantimes.co.jp', 45),
#  ('bangaloremirror.com', 22),
#  ('weeklytimesnow.com.au', 8),
#  ('seasidecourier.com', 5),
#  ('dover-express.co.uk', 1),
#  ('thearabdailynews.com', 1),
#  ('al-monitor.com', 5),
#  ('myanmarroom.com', 379),
#  ('restaurantnews.com', 5),
#  ('batleynews.co.uk', 3),
#  ('therakyatpost.com', 41),
#  ('thetimesherald.com', 11),
#  ('wcyb.com', 43),
#  ('gq-magazine.co.uk', 13),
#  ('thezebra.com', 1),
#  ('wimsradio.com', 27),
#  ('borderwatch.com.au', 25),
#  ('thedroidguy.com', 3),
#  ('koreabizwire.com', 6),
#  ('blouinnews.com', 11),
#  ('wtam.com', 3),
#  ('ajeyarao.com', 1),
#  ('rwdmag.com', 2),
#  ('econotimes.com', 85),
#  ('familylawweek.co.uk', 1),
#  ('canadianarchitect.com', 1),
#  ('peoplesdailyng.com', 9),
#  ('ljworld.com', 8),
#  ('kfyo.com', 4),
#  ('metrojacksonville.com', 16),
#  ('meor.org', 1),
#  ('rustonleader.com', 1),
#  ('sundaymail.co.zw', 2),
#  ('ottawasun.com', 25),
#  ('xboxed.net', 1),
#  ('themonitor.com', 74),
#  ('bozemandailychronicle.com', 19),
#  ('christianexaminer.com', 4),
#  ('bluenc.com', 6),
#  ('lsm.lv', 1),
#  ('wsaw.com', 5),
#  ('sundaytimes.lk', 10),
#  ('springfieldnewssun.com', 43),
#  ('amren.com', 1),
#  ('expertreviews.co.uk', 40),
#  ('pmlive.com', 2),
#  ('murphysboroamerican.com', 3),
#  ('tech.co', 61),
#  ('dailynorthshore.com', 3),
#  ('segmentnext.com', 12),
#  ('680news.com', 43),
#  ('gottabemobile.com', 119),
#  ('thedailycroton.com', 85),
#  ('polishgazette.com', 2),
#  ('ew.com', 43),
#  ('rifuture.org', 2),
#  ('baltimorepostexaminer.com', 4),
#  ('wallstreet-online.de', 18),
#  ('lakeplacidnews.com', 33),
#  ('galwayindependent.com', 5),
#  ('propertyweek.com', 2),
#  ('disrupt-africa.com', 2),
#  ('dailycaller.com', 31),
#  ('vogue.in', 2),
#  ('coachcal.com', 1),
#  ('cornishman.co.uk', 7),
#  ('bitterwallet.com', 23),
#  ('bardsandsages.com', 1),
#  ('bulawayo24.com', 15),
#  ('hometown-pasadena.com', 1),
#  ('healthaffairs.org', 1),
#  ('gokunming.com', 3),
#  ('bernardgoldberg.com', 2),
#  ('loft.is', 1),
#  ('nlmk.com', 1),
#  ('cpr.org', 2),
#  ('kickoff.com', 2),
#  ('nevadadailymail.com', 1),
#  ('theweathernetwork.com', 2),
#  ('heraldbulletin.com', 27),
#  ('beauregarddailynews.net', 2),
#  ('mysouthborough.com', 1),
#  ('wemu.org', 12),
#  ('diplomat.so', 5),
#  ('ausbt.com.au', 3),
#  ('wfp.org', 1),
#  ('northernnewenglandvillages.com', 1),
#  ('timesreview.com', 3),
#  ('financialexpress.com', 96),
#  ('cgiar.org', 1),
#  ('mcdonoughvoice.com', 3),
#  ('adelaidenow.com.au', 107),
#  ('beachbody.com', 2),
#  ('kfyi.com', 3),
#  ('cumbernauld-news.co.uk', 1),
#  ('wescomputing.com', 30),
#  ('thestringer.com.au', 2),
#  ('etcanada.com', 8),
#  ('3ders.org', 16),
#  ('archauthority.com', 1),
#  ('socialistworker.org', 2),
#  ('renewablesbiz.com', 1),
#  ('arklatexhomepage.com', 12),
#  ('augustafreepress.com', 19),
#  ('ahram.org.eg', 12),
#  ('fudzilla.com', 1),
#  ('ecorazzi.com', 1),
#  ('wfae.org', 6),
#  ('eveningexpress.co.uk', 18),
#  ('brand-e.biz', 4),
#  ('dannymorrison.com', 1),
#  ('marinelog.com', 1),
#  ('timminspress.com', 1),
#  ('localsyr.com', 41),
#  ('freekeene.com', 1),
#  ('capenews.net', 1),
#  ('amateurphotographer.co.uk', 1),
#  ('dailyorange.com', 6),
#  ('autotalk.com', 1),
#  ('thebusinessjournal.com', 12),
#  ('collegehumor.com', 1),
#  ('bloomberg.com', 149),
#  ('komando.com', 41),
#  ('dailystar.com.lb', 12),
#  ('belfasttelegraph.co.uk', 59),
#  ('onemk.co.uk', 5),
#  ('dailypioneer.com', 15),
#  ('panelsonpages.com', 1),
#  ('realtor.com', 6),
#  ('comingsoon.net', 6),
#  ('woodburybulletin.com', 2),
#  ('fightnews.com', 2),
#  ('newscaststudio.com', 1),
#  ('stlpublicradio.org', 3),
#  ('edenmagnet.com.au', 33),
#  ('bracknellnews.co.uk', 8),
#  ('ebrandz.com', 1),
#  ('sloughobserver.co.uk', 6),
#  ('memphisflyer.com', 3),
#  ('counton2.com', 23),
#  ('rocklandtimes.com', 1),
#  ('christiantoday.com.au', 5),
#  ('thereel.scroll.in', 2),
#  ('hpr2.org', 1),
#  ('chipchick.com', 6),
#  ('archinect.com', 3),
#  ('sunshinestatenews.com', 5),
#  ('nichegamer.com', 2),
#  ('builderonline.com', 11),
#  ('messenger-inquirer.com', 28),
#  ('consumerist.com', 26),
#  ('chennaionline.com', 27),
#  ('jaybossng.com', 1),
#  ('minnpost.com', 12),
#  ('alpeshkumar.com', 1),
#  ('spendmatters.com', 10),
#  ('blogspot.com', 674),
#  ('laconiadailysun.com', 1),
#  ('usmts.com', 3),
#  ('newschannel9.com', 25),
#  ('timesrecordnews.com', 11),
#  ('necn.com', 12),
#  ('inferse.com', 13),
#  ('valuewalk.com', 124),
#  ('worcestermag.com', 4),
#  ('tvtonight.com.au', 6),
#  ('livelaw.in', 1),
#  ('datacenterdynamics.com', 12),
#  ('collider.com', 12),
#  ('csoonline.com', 27),
#  ('citizen-times.com', 14),
#  ('kentuckyteacher.org', 2),
#  ('mfr.co.uk', 6),
#  ('cairoscene.com', 8),
#  ('thebeijinger.com', 14),
#  ('power99.com', 8),
#  ('pbn.com', 2),
#  ('vallartadaily.com', 1),
#  ('blouinartinfo.com', 8),
#  ('in-cumbria.com', 2),
#  ('worcesternews.co.uk', 13),
#  ('180dfo.com', 6),
#  ('statepress.com', 3),
#  ('lansingcitypulse.com', 2),
#  ('cape-coral-daily-breeze.com', 5),
#  ('mainetoday.com', 1),
#  ('indiatimes.com', 633),
#  ('fsunews.com', 1),
#  ('eatonvilletorainier.com', 1),
#  ('smallbiztrends.com', 57),
#  ('kcbd.com', 33),
#  ('lfpress.com', 14),
#  ('tert.am', 8),
#  ('cartrade.com', 1),
#  ('indiedb.com', 49),
#  ('fodors.com', 3),
#  ('zawya.com', 85),
#  ('wsbradio.com', 42),
#  ('readfearn.com', 1),
#  ('eagletribune.com', 24),
#  ('altweeklies.com', 1),
#  ('insidefutures.com', 2),
#  ('mining.com', 3),
#  ('ldnews.com', 14),
#  ('ghanainfrance.com', 1),
#  ('wineoscope.com', 1),
#  ('discovery.com', 20),
#  ('travelsofadam.com', 1),
#  ('stpaulsreview.com', 1),
#  ('infiniteunknown.net', 24),
#  ('popdust.com', 5),
#  ('askmen.com', 25),
#  ('panow.com', 2),
#  ('moultrienews.com', 5),
#  ('standard-democrat.com', 2),
#  ('thessdreview.com', 1),
#  ('alshahid.net', 1),
#  ('forbesadvocate.com.au', 27),
#  ('justcurious.co.za', 1),
#  ('yourdemocracy.net.au', 2),
#  ('dinner-mom.com', 1),
#  ('memeburn.com', 19),
#  ('wday.com', 8),
#  ('graphicpolicy.com', 1),
#  ('cornwallnewswatch.com', 1),
#  ('bwog.com', 8),
#  ('capecodonline.com', 1),
#  ('ajot.com', 4),
#  ('wired.com', 144),
#  ('sudanvisiondaily.com', 11),
#  ('proboxing-fans.com', 2),
#  ('boxing.com', 1),
#  ('thefastmode.com', 7),
#  ('putnamstandard.com', 1),
#  ('pressofatlanticcity.com', 1),
#  ('therawfoodworld.com', 14),
#  ('peconicpublicbroadcasting.org', 20),
#  ('environmentalleader.com', 2),
#  ('pchrgaza.org', 5),
#  ('ibn-tv.com', 1),
#  ('billboard.com', 97),
#  ('fijione.tv', 2),
#  ('thefifthestate.com.au', 1),
#  ('fiercecio.com', 16),
#  ('bangkokbiznews.com', 1),
#  ('nigeriamasterweb.com', 1),
#  ('elkharttruth.com', 2),
#  ('fishingworld.com.au', 1),
#  ('newescapologist.co.uk', 1),
#  ('allkpop.com', 17),
#  ('spectator.org', 6),
#  ('testing-blog.com', 14),
#  ('autorentalnews.com', 2),
#  ('usmission.gov', 1),
#  ('realclearpolitics.com', 7),
#  ('nbr.co.nz', 4),
#  ('fiercegovernmentit.com', 4),
#  ('bonhamjournal.com', 32),
#  ('healthitsecurity.com', 1),
#  ('maconlysource.com', 1),
#  ('medicalxpress.com', 8),
#  ('searchenginejournal.com', 52),
#  ('nashvillegab.com', 4),
#  ('chalkbeat.org', 1),
#  ('getsurrey.co.uk', 9),
#  ('staradvertiserblogs.com', 1),
#  ('tenterfieldstar.com.au', 24),
#  ('globest.com', 8),
#  ('theouterhaven.net', 1),
#  ('canoe.com', 3),
#  ('campaignasia.com', 25),
#  ('delilahdevlin.com', 1),
#  ('livenews.co.nz', 4),
#  ('taxjusticeblog.org', 1),
#  ('northernargus.com.au', 27),
#  ('stwnewspress.com', 12),
#  ('miamiherald.com', 59),
#  ('investorschronicle.co.uk', 1),
#  ('tbo.com', 30),
#  ('jeffwise.net', 1),
#  ('scicasts.com', 2),
#  ('bucyrustelegraphforum.com', 17),
#  ('signalscv.com', 8),
#  ('underlyingvalueinvestor.com', 1),
#  ('gameranx.com', 13),
#  ('parramattasun.com.au', 25),
#  ('charter97.org', 2),
#  ('abc30.com', 21),
#  ('livepunjab.com', 2),
#  ('oakpark.com', 1),
#  ('lynnnews.co.uk', 1),
#  ('nbcchicago.com', 15),
#  ('fullstory.com', 1),
#  ('ericgoldman.org', 2),
#  ('wlrfm.com', 1),
#  ('pinkrecipebox.com', 1),
#  ('fieldtechnologiesonline.com', 2),
#  ('610kvnu.com', 42),
#  ('opendemocracy.net', 8),
#  ('engineering.com', 6),
#  ('stereogum.com', 10),
#  ('aboutmyarea.co.uk', 3),
#  ('akilanews.com', 31),
#  ('closerweekly.com', 1),
#  ('westernwheel.com', 1),
#  ('kathyschiffer.com', 1),
#  ('moviehole.net', 1),
#  ('thedailyreporter.com', 2),
#  ('gnnliberia.com', 1),
#  ('dtg.org.uk', 3),
#  ('technomadia.com', 1),
#  ('abc7.com', 28),
#  ('blogto.com', 5),
#  ('thepioneer.com.pk', 5),
#  ('thebatt.com', 2),
#  ('aimislam.com', 1),
#  ('lite987.com', 1),
#  ('thecamarilloacorn.com', 2),
#  ('brobible.com', 34),
#  ('techgadgetcentral.com', 16),
#  ('baltimoresun.com', 19),
#  ('ereadernewstoday.com', 4),
#  ('sdgln.com', 2),
#  ('lifehacker.com', 74),
#  ('2paragraphs.com', 17),
#  ('mauitime.com', 2),
#  ('languagemonitor.com', 1),
#  ('velvetparkmedia.com', 2),
#  ('groundviews.org', 2),
#  ('e-know.ca', 1),
#  ('citifmonline.com', 22),
#  ('pal-item.com', 8),
#  ('musicinafrica.net', 2),
#  ('theeyeopener.com', 1),
#  ('bigbendnow.com', 2),
#  ('comicbook.com', 15),
#  ('cntraveler.com', 6),
#  ('simivalleyacorn.com', 2),
#  ('rpmonline.com.au', 2),
#  ('wrestlingnewssource.com', 3),
#  ('sloan.ca', 1),
#  ('djc.com', 4),
#  ('thewestonforum.com', 2),
#  ('khon2.com', 5),
#  ('infonews.co.nz', 3),
#  ('fwi.co.uk', 1),
#  ('lorrainespence.com', 1),
#  ('cjonline.com', 20),
#  ('advisor.ca', 3),
#  ('nojitter.com', 3),
#  ('ibtimes.com', 145),
#  ('verycd.com', 1),
#  ('thepublicslate.com', 1),
#  ('novuslight.com', 3),
#  ('expatica.com', 3),
#  ('monevator.com', 1),
#  ('e-magazine-voice.com', 6),
#  ('brightonpittsfordpost.com', 3),
#  ('aegee.org', 1),
#  ('itproportal.com', 59),
#  ('azpbs.org', 2),
#  ('lmfm.ie', 2),
#  ('wvah.com', 11),
#  ('caffeinatedthoughts.com', 2),
#  ('witneygazette.co.uk', 8),
#  ('dailynews.lk', 3),
#  ('mtu.edu', 1),
#  ('newstimeafrica.com', 1),
#  ('igamingbusiness.com', 1),
#  ('channel5.com', 11),
#  ('thecoastnews.com', 1),
#  ('atwonline.com', 2),
#  ('chinadaily.com.cn', 48),
#  ('radiox.co.uk', 4),
#  ('newafricabusinessnews.com', 1),
#  ('ibamag.com', 5),
#  ('mtexpress.com', 1),
#  ('cruxnow.com', 7),
#  ('thesixthaxis.com', 18),
#  ('androidpit.com', 1),
#  ('indiancarsbikes.in', 6),
#  ('gazetteherald.co.uk', 15),
#  ('heraldextra.com', 26),
#  ('masterherald.com', 13),
#  ('animationmagazine.net', 4),
#  ('exchangerates.org.uk', 1),
#  ('adnkronos.com', 1),
#  ('redding.com', 40),
#  ('systec.co.cr', 4),
#  ('iluvcinema.in', 5),
#  ('theath.ca', 2),
#  ('myajc.com', 3),
#  ('key103.co.uk', 7),
#  ('aviationweek.com', 2),
#  ('syrianobserver.com', 1),
#  ('wwl.com', 137),
#  ('dissexpress.co.uk', 1),
#  ('tvnewscheck.com', 14),
#  ('graziadaily.co.uk', 3),
#  ('stmarysstar.com.au', 2),
#  ('norcalminis.com', 1),
#  ('swxrightnow.com', 1),
#  ('societyforscience.org', 1),
#  ('chillicothenews.com', 2),
#  ('1prime.biz', 2),
#  ('ku.edu', 1),
#  ('espncricinfo.com', 5),
#  ('dodlive.mil', 1),
#  ('eprahaar.in', 3),
#  ('news1130.com', 38),
#  ('thewestmorlandgazette.co.uk', 16),
#  ('kearneycourier.com', 1),
#  ('radiotoday.co.uk', 3),
#  ('clatl.com', 2),
#  ('centralmaine.com', 35),
#  ('timeout.com.hk', 2),
#  ('wkyufm.org', 2),
#  ('sojo.net', 2),
#  ('thequietus.com', 7),
#  ('realitywanted.com', 1),
#  ('sott.net', 42),
#  ('recentlyheard.com', 2),
#  ('greenwichtime.com', 140),
#  ('uindy.edu', 1),
#  ('lawyerherald.com', 8),
#  ('classicalite.com', 11),
#  ('wmky.org', 2),
#  ('leaderandtimes.com', 1),
#  ('gq.com', 11),
#  ('cctv-america.com', 3),
#  ('jonathanturley.org', 1),
#  ('jouelzy.com', 1),
#  ('villagesoup.com', 48),
#  ('eteknix.com', 43),
#  ('rinf.com', 16),
#  ('minews26.com', 2),
#  ('internationalliving.com', 5),
#  ('dubonsonpourtestuyaux.com', 1),
#  ('euroweeklynews.com', 3),
#  ('channelworld.in', 28),
#  ('presstelegraph.com', 8),
#  ('libdemvoice.org', 7),
#  ('fayobserver.com', 1),
#  ('bgr.com', 171),
#  ('graziadaily.co.za', 2),
#  ('pagecounty.net', 8),
#  ('cesweb.org', 1),
#  ('dailyherald.com', 25),
#  ('24tanzania.com', 1),
#  ('stanforddaily.com', 6),
#  ('lethbridgeherald.com', 62),
#  ('bankinfosecurity.com', 7),
#  ('sjrnews.com', 2),
#  ('fandompost.com', 13),
#  ('savannahnow.com', 20),
#  ('hartsvillevidette.com', 3),
#  ('khqa.com', 25),
#  ('eyeontaiwan.com', 4),
#  ('euroleague.net', 1),
#  ('gossipandgab.com', 103),
#  ('kval.com', 33),
#  ('ballparkdigest.com', 1),
#  ('ckom.com', 1),
#  ('cantondailyledger.com', 2),
#  ('argusobserver.com', 1),
#  ('theglobeandmail.com', 93),
#  ('newsone.com', 9),
#  ('heraldpalladium.com', 2),
#  ('oblogdeeoblogda.me', 2),
#  ('broadcastnow.co.uk', 3),
#  ('flatheadbeacon.com', 4),
#  ('androidheadlines.com', 538),
#  ('mromagazine.com', 13),
#  ('pravdareport.com', 1),
#  ('ephotozine.com', 6),
#  ('animationinsider.com', 7),
#  ('thespec.com', 59),
#  ('businesscar.co.uk', 1),
#  ('news4u.co.in', 1),
#  ('newstalkflorida.com', 1),
#  ('fairport-erpost.com', 4),
#  ('chinaeconomicreview.com', 1),
#  ('sentinel-standard.com', 3),
#  ('marketplace.org', 12),
#  ('littlehamptongazette.co.uk', 2),
#  ('vinereport.com', 6),
#  ('juiceonline.com', 2),
#  ('bayoubuzz.com', 2),
#  ('ivn.us', 7),
#  ('day-news.net', 169),
#  ('internationalpeaceandconflict.org', 473),
#  ('lse.ac.uk', 2),
#  ('inlander.com', 6),
#  ('selmatimesjournal.com', 2),
#  ('game-debate.com', 7),
#  ('nysepost.com', 51),
#  ('dailyindependent.com', 16),
#  ('dailyvoice.com', 36),
#  ('rep-am.com', 16),
#  ('abc6onyourside.com', 57),
#  ('chinatopix.com', 45),
#  ('makeuseof.com', 98),
#  ('ocala.com', 14),
#  ('freedomoutpost.com', 324),
#  ('avenuemail.in', 2),
#  ('angrysummit.com', 9),
#  ('donegaldemocrat.ie', 1),
#  ('m.kauppalehti.fi', 2),
#  ('priyo.com', 6),
#  ('whdh.com', 36),
#  ('utahpulse.com', 1),
#  ('shorelinebeacon.com', 2),
#  ('fcsvirginia.org', 1),
#  ('timefortruth.eu', 11),
#  ('1stwebdesigner.com', 1),
#  ('auto123.com', 4),
#  ('rdmag.com', 13),
#  ('thebeacon.net', 1),
#  ('mcknights.com', 2),
#  ('atlantaintownpaper.com', 2),
#  ('borgenproject.org', 3),
#  ('forexcrunch.com', 2),
#  ('investorsbusinessdigest.com', 1),
#  ('pinkbike.com', 1),
#  ('zesterdaily.com', 1),
#  ('themreport.com', 1),
#  ('staffingindustry.com', 1),
#  ('morleyobserver.co.uk', 3),
#  ('skyvalleychronicle.com', 5),
#  ('themarshalltown.com', 9),
#  ('centraladvocate.com.au', 23),
#  ('cosmeticsdesign-asia.com', 2),
#  ('newarkadvertiser.co.uk', 2),
#  ('rottentomatoes.com', 6),
#  ('worldne.ws', 42),
#  ('hybridcars.com', 6),
#  ('webb-site.com', 1),
#  ('wandtv.com', 24),
#  ('healthcaredive.com', 3),
#  ('bizedge.co.nz', 4),
#  ('greatergreaterwashington.org', 29),
#  ('bovinevetonline.com', 1),
#  ('realmofgaming.com', 1),
#  ('thekimsixfix.com', 1),
#  ('harlandaily.com', 5),
#  ('essence.com', 3),
#  ('spin1038.com', 3),
#  ('kgw.com', 36),
#  ('hemmings.com', 4),
#  ('nag.co.za', 3),
#  ('clintonherald.com', 15),
#  ('rfa.org', 1),
#  ('newsledge.com', 16),
#  ('southdadenewsleader.com', 1),
#  ('thailandwebhotel.com', 1),
#  ('newscientist.com', 15),
#  ('athensreview.com', 11),
#  ('elon.edu', 1),
#  ('rcrwireless.com', 40),
#  ('gmatclub.com', 31),
#  ('helihub.com', 1),
#  ('i-programmer.info', 2),
#  ('alternet.org', 19),
#  ('montanaroue.com', 4),
#  ('pressconnects.com', 10),
#  ('wearemoviegeeks.com', 3),
#  ('wibx950.com', 8),
#  ('imperialvalleynews.com', 9),
#  ('easternmirrornagaland.com', 6),
#  ('registercitizen.com', 10),
#  ('murfreesboropost.com', 1),
#  ('middaydaily.com', 12),
#  ('manchestereveningnews.co.uk', 43),
#  ('ktvn.com', 55),
#  ('omojuwa.com', 5),
#  ('mywabashvalley.com', 27),
#  ('hallmarknews.com', 1),
#  ('siliconera.com', 20),
#  ('forbes.com', 17),
#  ('ablogtowatch.com', 1),
#  ('livetradingnews.com', 22),
#  ('unternehmen-heute.de', 2),
#  ('foodsquare.net', 1),
#  ('dawn.com', 63),
#  ('spiked-online.com', 3),
#  ('psnation.com', 1),
#  ('waynecojournalbanner.com', 3),
#  ('washingtonpost.com', 323),
#  ('mycountry955.com', 1),
#  ('abc19.tv', 1),
#  ('insidermonkey.com', 4),
#  ('mmanews.com', 3),
#  ('justice.gov', 4),
#  ('jalopnik.com', 38),
#  ('deviantart.com', 19),
#  ('ecdailynews.com', 2),
#  ('ontopmag.com', 6),
#  ('gamersftw.co.uk', 4),
#  ('wvnstv.com', 2),
#  ('dailypress.net', 9),
#  ('newratings.com', 2),
#  ('rustourismnews.com', 1),
#  ('gainako.com', 1),
#  ('thecoachessite.com', 1),
#  ('watershedpost.com', 4),
#  ('centralfloridafuture.com', 3),
#  ('gazette-news.co.uk', 17),
#  ('kansas.com', 18),
#  ('investors.com', 86),
#  ('sawatdeenetwork.com', 2),
#  ('geeksnack.com', 3),
#  ('rafu.com', 1),
#  ('1075theriver.com', 13),
#  ('vancouverisland.ctvnews.ca', 1),
#  ('nmpolitics.net', 1),
#  ('coloradoindependent.com', 1),
#  ('wjct.org', 10),
#  ('surinenglish.com', 1),
#  ('breitbart.com', 104),
#  ('thejournal.com', 9),
#  ('kaumudiglobal.com', 2),
#  ('horror-movies.ca', 4),
#  ('oregonmusicnews.com', 3),
#  ('dailyexaminer.com.au', 25),
#  ('southernminn.com', 2),
#  ('westernmassnews.com', 34),
#  ('tvtechnology.com', 10),
#  ('wblakegray.com', 1),
#  ('virtual-strategy.com', 301),
#  ('saharasamay.com', 8),
#  ('avn.com', 16),
#  ('kiro7.com', 4),
#  ('borneobulletin.com.bn', 19),
#  ('hulldailymail.co.uk', 6),
#  ('spain-holiday.com', 1),
#  ('mix96.co.uk', 25),
#  ('wallstreethedge.com', 7),
#  ('bakingbusiness.com', 1),
#  ('570news.com', 44),
#  ('tvinsider.com', 1),
#  ('euobserver.com', 4),
#  ('thegleaner.com', 1),
#  ('zap2it.com', 19),
#  ('newschannel10.com', 39),
#  ('maritimesecurity.asia', 1),
#  ('dailycardinal.com', 3),
#  ('intheblack.com', 4),
#  ('givemeliberty01.com', 11),
#  ('nycnews.net', 1),
#  ('nexthttp.com', 1),
#  ('rferl.org', 8),
#  ('kunc.org', 3),
#  ('courant.com', 33),
#  ('dobianchi.com', 1),
#  ('order-order.com', 22),
#  ('spoilertv.com', 9),
#  ('midweekherald.co.uk', 1),
#  ('tulsaworld.com', 17),
#  ('ibtimes.co.in', 92),
#  ('steveheimoff.com', 4),
#  ('indiandownunder.com.au', 1),
#  ('howstuffworks.com', 4),
#  ('saharareporters.com', 2),
#  ('alamosanews.com', 1),
#  ('pitchfork.com', 21),
#  ('silverdoctors.com', 1),
#  ('product-reviews.net', 12),
#  ('kcci.com', 15),
#  ('insidevancouver.ca', 1),
#  ('theislandnow.com', 3),
#  ('stluciastar.com', 1),
#  ('cogconnected.com', 4),
#  ('tor.com', 19),
#  ('japanbuzz.info', 1),
#  ('jmir.org', 6),
#  ('sugarscape.com', 6),
#  ('hiddenremote.com', 5),
#  ('opb.org', 43),
#  ('tucsonnewsnow.com', 37),
#  ('am1150.ca', 4),
#  ('scmagazine.com', 15),
#  ('nextcity.org', 3),
#  ('broomfieldenterprise.com', 1),
#  ('news12.com', 1),
#  ('kfvs12.com', 28),
#  ('americanclarion.com', 1),
#  ('growapineapple.com', 1),
#  ('hebdenbridgetimes.co.uk', 3),
#  ('nbcmontana.com', 44),
#  ('registerguard.com', 36),
#  ('dallasobserver.com', 10),
#  ('mnsun.com', 3),
#  ('millzero.com', 1),
#  ('deadspin.com', 7),
#  ('news.gnom.es', 81),
#  ('delcotimes.com', 11),
#  ('westword.com', 6),
#  ('greentechmedia.com', 3),
#  ('aurn.com', 7),
#  ('greaterkashmir.com', 1),
#  ('theguardian.pe.ca', 1),
#  ('erau.edu', 1),
#  ('vizworld.com', 1),
#  ('mobilechoiceuk.com', 1),
#  ('wtvm.com', 35),
#  ('chathamdailynews.ca', 8),
#  ('crawleyobserver.co.uk', 1),
#  ('macaudailytimes.com.mo', 5),
#  ('ipwatchdog.com', 8),
#  ('takepart.com', 9),
#  ('irishtimes.com', 117),
#  ('plaintalk.net', 1),
#  ('mtv.com.au', 5),
#  ('thewesternstar.com', 2),
#  ('dublinpeople.com', 2),
#  ('gamewatcher.com', 2),
#  ('hardocp.com', 25),
#  ('berroco.com', 1),
#  ('ladailypost.com', 3),
#  ('mu.dah.my', 6),
#  ('somalilandsun.com', 3),
#  ('farmandranchguide.com', 1),
#  ('yourhoustonnews.com', 34),
#  ('sunstar.com.ph', 22),
#  ('illinoisentertainer.com', 1),
#  ('thesaturdaypaper.com.au', 3),
#  ('cleantechnica.com', 125),
#  ('dailypost.ng', 3),
#  ('sulphurdailynews.com', 8),
#  ('almanacnews.com', 3),
#  ('kitchenz.link', 1),
#  ('kake.com', 4),
#  ('n4g.com', 23),
#  ('brides.com', 3),
#  ('ahherald.com', 1),
#  ('hamlethub.com', 5),
#  ('thesheridanpress.com', 1),
#  ('etftrends.com', 3),
#  ('dealnews.com', 49),
#  ('dupontregistry.com', 10),
#  ('thetelegram.com', 10),
#  ('dotchuoinon.com', 1),
#  ('theappalachianonline.com', 1),
#  ('yourtango.com', 17),
#  ('dailybulletin.com', 16),
#  ('which-50.com', 1),
#  ('health24.com', 5),
#  ('windsorsquare.ca', 2),
#  ('wkrg.com', 22),
#  ('foxla.com', 44),
#  ('tanzanianewsreports.com', 3),
#  ('thenewstribe.com', 6),
#  ('dettecakes.com', 1),
#  ('epinula.com', 1),
#  ('vox.com', 20),
#  ('sentinelandenterprise.com', 13),
#  ('gamerscorewhores.com', 1),
#  ('thesuntimes.com', 3),
#  ('marinecorpstimes.com', 2),
#  ('campaignlive.co.uk', 52),
#  ('hemeltoday.co.uk', 3),
#  ('thenewscenter.tv', 4),
#  ('interfax.com.ua', 2),
#  ('hottytoddy.com', 2),
#  ('thecrimson.com', 2),
#  ('yankees101.com', 1),
#  ('gainesvilleregister.com', 12),
#  ('wcax.com', 24),
#  ('centralctcommunications.com', 11),
#  ('laptopmag.com', 1),
#  ('amarillo.com', 5),
#  ('wpmobserver.com', 7),
#  ('garethcliff.com', 1),
#  ('middlewichguardian.co.uk', 9),
#  ('multihousingnews.com', 2),
#  ('americanprogress.org', 2),
#  ('wanderlustandlipstick.com', 1),
#  ('ottumwacourier.com', 11),
#  ('esc-pod.com', 1),
#  ('abc10.com', 12),
#  ('thechocolatevoice.com', 1),
#  ('michellegielan.com', 3),
#  ('thehawkindia.com', 7),
#  ('my40.tv', 25),
#  ('sequimgazette.com', 2),
#  ('blackamericaweb.com', 10),
#  ('desdemonadespair.net', 9),
#  ('celebritynetworth.com', 6),
#  ('watchdog.org', 5),
#  ('4hoteliers.com', 18),
#  ('socialitelife.com', 3),
#  ('idahostatesman.com', 25),
#  ('peacefmonline.com', 11),
#  ('entertainment.ie', 27),
#  ('wbco.com', 5),
#  ('cuindependent.com', 1),
#  ('hotpopsyrup.com', 1),
#  ('reviewtimes.com', 35),
#  ('wbir.com', 9),
#  ('mainestripper.com', 1),
#  ('wirefm.com', 5),
#  ('splitsider.com', 8),
#  ('wrestlezone.com', 29),
#  ('whyisrael.org', 1),
#  ('enenews.com', 4),
#  ('connectstatesboro.com', 19),
#  ('insidercarnews.com', 3),
#  ('warriortradingnews.com', 1),
#  ('destructoid.com', 122),
#  ('adobe.com', 1),
#  ('naturalproductsinsider.com', 2),
#  ('eveningsun.com', 15),
#  ...]

# %%
import math

# %%
ton = TONE[['date','tone', 'positive', 'negative', 'polarity', 'activ_den', 'self_den','agency', 'price']].copy()
ton.head()
# Out:
#                  date      tone  positive  negative  polarity  activ_den  \
# 0 2016-01-01 00:00:00       NaN       NaN       NaN       NaN        NaN
# 1 2016-01-01 00:15:00 -1.503165  2.215190  3.718354  5.933544  22.468354
# 2 2016-01-01 00:15:00 -0.239808  3.357314  3.597122  6.954436  21.902478
# 3 2016-01-01 00:15:00 -2.764977  2.534562  5.299539  7.834101  21.006144
# 4 2016-01-01 00:15:00  6.430155  7.982262  1.552106  9.534368  22.912047
#
#    self_den                       agency  price
# 0       NaN                          NaN    NaN
# 1  0.474684                    fox17.com    NaN
# 2  3.517186                 nwitimes.com    NaN
# 3  1.036866  theunitedvoiceofamerica.com    NaN
# 4  1.626016           comicsalliance.com    NaN

# %%
ton_ag = sorted(agencies_lst, key=lambda x:x[1], reverse=True)

TOP_tones = pd.DataFrame({'date': [], 'price': []})

TOP_tones['date'] = TONE.date.unique()
TOP_tones['price'] = TOP_tones[['date']].merge(period_df,how='left').price

for el in ton_ag: #[:100]:
    temp = pd.DataFrame({'date': TONE.date.unique(), 'agency': [el[0]]*len(TONE.date.unique()) , el[0]: None})
    try:
        temp[el[0]] = temp[['date', 'agency']].merge(TONE, how='left').tone
        TOP_tones[el[0]] = temp[el[0]]
    except ValueError:
        print("Nan was as data")
# Out:
# Nan was as data

# %%
TOP_tones.head()
# Out:
#                  date  price  yahoo.com  haberajans.net  \
# 0 2016-01-01 00:00:00    NaN        NaN             NaN
# 1 2016-01-01 00:15:00    NaN  -1.853306             NaN
# 2 2016-01-01 00:30:00    NaN  -5.526770             NaN
# 3 2016-01-01 00:45:00    NaN   1.187403             NaN
# 4 2016-01-01 01:00:00    NaN  -0.606061             NaN
#
#    american-reporter.com  toptechnews.com  marketwatch.com  vtdigger.org  \
# 0                    NaN              NaN              NaN           NaN
# 1                    NaN              NaN              NaN           NaN
# 2                    NaN              NaN              NaN           NaN
# 3                    NaN              NaN              NaN           NaN
# 4                    NaN              NaN              NaN           NaN
#
#    4-traders.com  fltimes.com           ...             mironline.ca  \
# 0            NaN          NaN           ...                      NaN
# 1            NaN    -0.481928           ...                      NaN
# 2            NaN     2.088773           ...                      NaN
# 3            NaN     0.973236           ...                      NaN
# 4            NaN     1.503759           ...                      NaN
#
#    southernpacificreview.com  thescore.com  athleticsweekly.com  \
# 0                        NaN           NaN                  NaN
# 1                        NaN           NaN                  NaN
# 2                        NaN           NaN                  NaN
# 3                        NaN           NaN                  NaN
# 4                        NaN           NaN                  NaN
#
#    helpmeoutdoc.com  gregdisch.com  cerescourier.com  bigclassaction.com  \
# 0               NaN            NaN               NaN                 NaN
# 1               NaN            NaN               NaN                 NaN
# 2               NaN            NaN               NaN                 NaN
# 3               NaN            NaN               NaN                 NaN
# 4               NaN            NaN               NaN                 NaN
#
#    citywire.co.uk  legalbusinessonline.com
# 0             NaN                      NaN
# 1       -3.875969                      NaN
# 2             NaN                      NaN
# 3             NaN                      NaN
# 4             NaN                      NaN
#
# [5 rows x 10717 columns]

# %%
#TOP_tones.to_csv('TOP_TONES_Agencies.csv')

train = TOP_tones[TOP_tones.date < '2016-01-22 00:00:00']
test = TOP_tones[TOP_tones.date > '2016-01-25 00:00:00']

# %%
train.to_csv('trainTonesAG.csv')
test.to_csv('testTonesAG.csv')

# %%
prc = TOP_tones[TOP_tones.price.notnull()]
#prc = prc[prc.notnull()]

# %%
prc.head()
# Out:
#                    date    price  yahoo.com  haberajans.net  \
# 327 2016-01-04 09:45:00  752.810   0.504286             NaN
# 328 2016-01-04 10:00:00  755.542  -1.631854             NaN
# 329 2016-01-04 10:15:00  751.544  -2.569043             NaN
# 330 2016-01-04 10:30:00  749.900  -2.040816             NaN
# 331 2016-01-04 10:45:00  749.476  -6.728972             NaN
#
#      american-reporter.com  toptechnews.com  marketwatch.com  vtdigger.org  \
# 327                    NaN              NaN              NaN           NaN
# 328                    NaN              NaN              NaN           NaN
# 329                    NaN              NaN              NaN           NaN
# 330                    NaN              NaN              NaN           NaN
# 331                    NaN              NaN        -0.206612           NaN
#
#      4-traders.com  fltimes.com        ...         thestar.co.uk  elef.edu.mx  \
# 327            NaN          NaN        ...                   NaN          NaN
# 328            NaN          NaN        ...                   NaN          NaN
# 329            NaN          NaN        ...                   NaN          NaN
# 330       6.726457          NaN        ...                   NaN          NaN
# 331       2.732240          NaN        ...                   NaN          NaN
#
#      heardcitizen.com  gmenhq.com  thevolunteertimes.com  traveloni.com  \
# 327               NaN         NaN                    NaN            NaN
# 328               NaN         NaN                    NaN            NaN
# 329               NaN         NaN                    NaN            NaN
# 330               NaN         NaN                    NaN            NaN
# 331               NaN         NaN                    NaN            NaN
#
#      news.tj  mortgagenewsdaily.com  motoringexposure.com  testudotimes.com
# 327      NaN                    NaN                   NaN               NaN
# 328      NaN                    NaN                   NaN               NaN
# 329      NaN                    NaN                   NaN               NaN
# 330      NaN                    NaN                   NaN               NaN
# 331      NaN                    NaN                   NaN               NaN
#
# [5 rows x 10717 columns]

# %%
#list(prc.columns)

# %%
entity = list(prc.columns)[2:] # omit date and price
correlations = list(prc.corr()['price'])[1:] # omit price
lst = [[entity[x], correlations[x]] for x in range(len(correlations))]

# %%
print(lst)
# Out:
# [['yahoo.com', -0.06462616276034676], ['haberajans.net', 0.062011724893251685], ['american-reporter.com', -0.00273371929040892], ['toptechnews.com', 0.10306812903861072], ['marketwatch.com', -0.01004744535473274], ['vtdigger.org', 0.0697798389405015], ['4-traders.com', -0.0718870726162366], ['fltimes.com', 0.15490535053745222], ['gizmodo.com.au', -0.022084239319971333], ['blogspot.com', 0.20122050726070936], ['huffingtonpost.com', -0.12043630241447746], ['pr-inside.com', -0.17058220545681804], ['wn.com', 0.08241543614836042], ['indiatimes.com', 
# %%
companies = sorted(lst, key=lambda x: x[1], reverse=True)
sel_companies = [el[0] for el in companies] # NO FILTER BY PEARSON CORRELATION
#sel_companies = [el[0] for el in companies if abs(el[1]) >= 0.20]

# %%
sel_companies
# Out:
# ['thewrap.com',
#  'geekwire.com',
#  'dhal3.com',
#  'itworld.com',
#  'stuff.co.nz',
#  'infoworld.com',
#  'cnsnews.com',
#  'theage.com.au',
#  'brisbanetimes.com.au',
#  'smh.com.au',
#  'gizmodo.com',
#  'usatoday.com',
#  'dawn.com',
#  'latimes.com',
#  'pressreleasepoint.com',
#  'triblive.com',
#  'cbslocal.com',
#  'clapway.com',
#  'clutchfans.net',
#  'wwl.com',
#  'californiaturkishtimes.com',
#  'pafoa.org',
#  'gulfnews.com',
#  'mtstandard.com',
#  'econotimes.com',
#  'theverge.com',
#  'nydailynews.com',
#  'walmart.com',
#  'wickedlocal.com',
#  'nytimes.com',
#  'kdhnews.com',
#  'greenfieldreporter.com',
#  'circuitwall.com',
#  'itweb.co.za',
#  'buzzstake.com',
#  'thetandd.com',
#  'outlookindia.com',
#  'sci-tech-today.com',
#  'timescolonist.com',
#  'chron.com',
#  'theaustralian.com.au',
#  'talentrefresh.com',
#  'lightreading.com',
#  'helenair.com',
#  'couriermail.com.au',
#  'wiscnews.com',
#  'mediapost.com',
#  'sfgate.com',
#  'siouxcityjournal.com',
#  'weei.com',
#  'newegg.com',
#  'ap.org',
#  'dailytelegraph.com.au',
#  'droid-life.com',
#  'menafn.com',
#  'pcmag.com',
#  'blogspot.com',
#  'examiner.com',
#  'gizmodo.in',
#  'burnabynow.com',
#  'virtual-strategy.com',
#  'wsj.com',
#  'metro.co.uk',
#  'indiatimes.com',
#  'newindianexpress.com',
#  'wingatewire.com',
#  'innercitypress.com',
#  'firstpost.com',
#  'gottabemobile.com',
#  'itbusinessnet.com',
#  'indiatoday.intoday.in',
#  'thestar.com.my',
#  'fltimes.com',
#  'phandroid.com',
#  'alaskahighwaynews.ca',
#  'iheart.com',
#  'csmonitor.com',
#  'mirror.co.uk',
#  'go.com',
#  'bloomberg.com',
#  'toucharcade.com',
#  'mis-asia.com',
#  'newshub.org',
#  'vice.com',
#  'billingsgazette.com',
#  'cbronline.com',
#  'ibtimes.com',
#  'ibtimes.co.uk',
#  'mic.com',
#  'toptechnews.com',
#  'techcrunch.com',
#  'theprovince.com',
#  'newkerala.com',
#  'newsok.com',
#  'business-standard.com',
#  'bgr.com',
#  'india.com',
#  'wn.com',
#  'bbc.co.uk',
#  'heraldsun.com.au',
#  'vtdigger.org',
#  'haberajans.net',
#  'environmentguru.com',
#  'mancunianmatters.co.uk',
#  'time.com',
#  'indianexpress.com',
#  'cio.com',
#  'mynorthwest.com',
#  'pcworld.com',
#  'androidcommunity.com',
#  'dailymail.co.uk',
#  'hutchnews.com',
#  'theworldlink.com',
#  'cleantechnica.com',
#  'nasdaq.com',
#  'jogleapp.co.uk',
#  'themalaymailonline.com',
#  'ctpost.com',
#  'techtimes.com',
#  'reuters.com',
#  'travelpod.com',
#  'local12.com',
#  'iol.co.za',
#  'telegraph.co.uk',
#  'american-reporter.com',
#  'tricitynews.com',
#  'businessinsider.in',
#  'marketwatch.com',
#  'cio-today.com',
#  'tucson.com',
#  'vancourier.com',
#  'gizmodo.com.au',
#  'prweb.com',
#  'cambridge-news.co.uk',
#  'lifehacker.com.au',
#  'softpedia.com',
#  'recode.net',
#  'vgchartz.com',
#  'androidpolice.com',
#  'ibtimes.com.au',
#  'perthnow.com.au',
#  'quadrangleonline.com',
#  'pocketnow.com',
#  'zennie62blog.com',
#  'cnn.com',
#  'seekingalpha.com',
#  'pressreleaserocket.net',
#  'yahoo.com',
#  'foxnews.com',
#  'huewire.com',
#  'ssuchronicle.com',
#  'destructoid.com',
#  '4-traders.com',
#  'greenwichtime.com',
#  'whatech.com',
#  'ign.com',
#  'hindustantimes.com',
#  'mouthshut.com',
#  'day-news.net',
#  'news.stv.tv',
#  'mobypicture.com',
#  'msn.com',
#  'zdnet.com',
#  'dnaindia.com',
#  'newsoptimist.ca',
#  'yorktonthisweek.com',
#  'huffingtonpost.com',
#  'contracostatimes.com',
#  'pokernews.com',
#  'mrtopstep.com',
#  'androidauthority.com',
#  'stltoday.com',
#  'firstdroid.com',
#  'huffingtonpost.co.uk',
#  'venturebeat.com',
#  'thevillagessuntimes.com',
#  'fool.com',
#  'pr-inside.com',
#  'myanmarroom.com',
#  'finanznachrichten.de',
#  'cnet.com',
#  'benzinga.com',
#  'skyscrapercity.com',
#  'washingtonpost.com',
#  'talkandroid.com',
#  'basearticles.com',
#  'internationalpeaceandconflict.org',
#  'jowhar.com',
#  'princegeorgecitizen.com',
#  'newsfactor.com',
#  'ndtv.com',
#  'theguardian.com',
#  'businessinsider.com',
#  'ecommerce-journal.com',
#  'kotaku.com.au',
#  'sys-con.com',
#  'jsonline.com',
#  'asiaone.com',
#  'freedomoutpost.com',
#  'eastniagarapost.com',
#  'businessinsider.com.au',
#  'themarysue.com',
#  'enterprise-security-today.com',
#  'latpro.com',
#  'businesswire.com',
#  'nzherald.co.nz',
#  'briefingwire.com',
#  'bsccomment.com',
#  'emiratesweek.com',
#  'tmcnet.com',
#  'business2community.com',
#  'thejakartapost.com',
#  'equities.com',
#  'newsroomamerica.com',
#  'androidheadlines.com',
#  'independent.ie',
#  'phonearena.com',
#  'marketingland.com',
#  'lcsun-news.com',
#  'irishtimes.com',
#  'variety.com',
#  'freerepublic.com',
#  'thehindu.com',
#  'chicagotribune.com',
#  'mashable.com',
#  'independent.co.uk',
#  'inquisitr.com',
#  'irishexaminer.com',
#  'thereminder.ca',
#  'eetimes.com',
#  'patch.com',
#  'engadget.com',
#  'philstar.com',
#  'richmond-news.com',
#  'delta-optimist.com',
#  'en.qantara.de',
#  'wired.com',
#  'castanet.net',
#  'stamfordadvocate.com',
#  'techradar.com',
#  'thestreet.com',
#  'efytimes.com',
#  'informationweek.com',
#  'channelnewsasia.com',
#  'valuewalk.com',
#  'mercurynews.com',
#  'punchjump.com',
#  'techaeris.com',
#  'networkworld.com',
#  'mobilesyrup.com',
#  'missoulian.com',
#  'fastcompany.com',
#  'startribune.com',
#  'watoday.com.au',
#  'livescience.com',
#  'bangkokpost.com',
#  'livenewscentral.com',
#  'neowin.net',
#  'politico.com',
#  'onlinenigeria.com',
#  'ktbb.com',
#  'cnbc.com',
#  'longisland.com',
#  'malaysiandigest.com',
#  'androidcentral.com',
#  'mentalfloss.com',
#  'billboard.com',
#  'canberratimes.com.au',
#  'afr.com',
#  'itnewsonline.com',
#  'bt.com.bn',
#  'adelaidenow.com.au',
#  'cbc.ca',
#  'ibtimes.co.in',
#  'wfmz.com',
#  'digitaltrends.com',
#  'prnewswire.co.in',
#  'thomhartmann.com',
#  'naztoday.com',
#  'trustedreviews.com',
#  'seattlepi.com',
#  'denverpost.com',
#  'deccanchronicle.com',
#  'nbcnews.com',
#  'thepublicopinion.com',
#  'thedrum.com',
#  'bbc.com',
#  'madison.com',
#  'phys.org',
#  'squamishchief.com',
#  'breitbart.com',
#  'computerworld.com',
#  'estevanmercury.ca',
#  'techcentral.ie',
#  'seriouslypolitics.com',
#  'livemint.com',
#  'entrepreneur.com',
#  'ausdroid.net',
#  'hwhills.com',
#  'ubergizmo.com',
#  'investmentunderground.com',
#  'slashgear.com',
#  'qctimes.com',
#  'foxreno.com',
#  'financialexpress.com',
#  'appleinsider.com',
#  'winonadailynews.com',
#  'adweek.com',
#  'fool.com.au',
#  'newsdaily.com',
#  'siliconangle.com',
#  'gamasutra.com',
#  'theglobeandmail.com',
#  'gizmodo.co.uk',
#  'usnews.com',
#  'lidtime.com',
#  'newstimes.com',
#  'moviepilot.com',
#  'news.com.au',
#  'gazette.com',
#  'gossipandgab.com',
#  'thompsoncitizen.net',
#  'space.com',
#  'pcadvisor.co.uk',
#  'makeuseof.com',
#  'newwestrecord.ca',
#  'techworld.com.au',
#  'geimin.co.uk',
#  'horizonpost.com',
#  'searchengineland.com',
#  'skyscraperpage.com',
#  'gantdaily.com',
#  'sltrib.com',
#  'alphr.com',
#  'cdanews.com',
#  'brandonsun.com',
#  'theregister.co.uk',
#  'ghanaweb.com',
#  'computerworld.com.sg',
#  'express.co.uk',
#  'rawstory.com',
#  'allafrica.com',
#  'therecord.com',
#  'zawya.com',
#  'mb.com.ph',
#  'hometownstations.com',
#  'tribune.com.pk',
#  'opednews.com',
#  'digise.com',
#  'streetinsider.com',
#  'hamiltonnews.com',
#  'beaumontenterprise.com',
#  'prlog.org',
#  'breakingnews.ie',
#  'celebcafe.org',
#  'lycos.com',
#  'bostonglobe.com',
#  'thedailycroton.com',
#  'bostonherald.com',
#  'investors.com',
#  'deadline.com',
#  'iclarified.com',
#  'lifehacker.com',
#  'medicinehatnews.com',
#  'eweek.com',
#  'hypebot.com',
#  'vancouversun.com',
#  'ktvz.com',
#  'tubefilter.com',
#  'wnd.com',
#  'insidehalton.com',
#  'digitaljournal.com',
#  'malaysia-chronicle.com',
#  'uproxx.com',
#  'broadwayworld.com',
#  'nationalpost.com',
#  'rappler.com',
#  'brandrepublic.com',
#  'globenewswire.com',
#  'cbsnews.com',
#  'theweek.com',
#  'theatlantic.com',
#  'arstechnica.co.uk',
#  'multichannel.com',
#  'clarksvilleonline.com',
#  'themonitor.com',
#  'news.gnom.es',
#  'investmentwatchblog.com',
#  'theherald.com.au',
#  'thestatesman.com',
#  'goldcoastbulletin.com.au',
#  'arstechnica.com',
#  'bizcommunity.com',
#  'lotterypost.com',
#  'theepochtimes.com',
#  'azdailysun.com',
#  'buzzfeed.com',
#  'nj.com',
#  'techdirt.com',
#  'bgr.in',
#  'ely-news.co.uk',
#  '12newsnow.com',
#  'technewsworld.com',
#  'washingtontimes.com',
#  'thedailystar.net',
#  'globalnews.ca',
#  'sasklifestyles.com',
#  'wcfcourier.com',
#  'financialcontent.com',
#  'canadianreviewer.com',
#  'pantagraph.com',
#  'kltv.com',
#  'asianage.com',
#  'mlive.com',
#  'irasciblemusings.com',
#  'azcentral.com',
#  'sagmart.com',
#  'wftv.com',
#  'roanoke.com',
#  'prnewswire.com',
#  'betanews.com',
#  'kdminer.com',
#  'ecommercetimes.com',
#  'wbap.com',
#  'voiceofalexandria.com',
#  'wral.com',
#  'abc-7.com',
#  'therepublic.com',
#  'inquirer.net',
#  'thepeoplescube.com',
#  'daytondailynews.com',
#  'fremonttribune.com',
#  'scmp.com',
#  'theblaze.com',
#  'khaleejtimes.com',
#  'saps.gov.za',
#  'ameripublications.com',
#  'themalaysianinsider.com',
#  'newsmax.com',
#  'aero-news.net',
#  'wlox.com',
#  'herald-review.com',
#  'tvovermind.com',
#  'leadercall.com',
#  'straitstimes.com',
#  'senegal-actu.com',
#  'myfinancereporter.com',
#  'greenbot.com',
#  'soyacincau.com',
#  'bidnessetc.com',
#  'wkbw.com',
#  'salon.com',
#  'seattletimes.com',
#  'standard.co.uk',
#  'nwitimes.com',
#  'lacrossetribune.com',
#  'hollywoodreporter.com',
#  'whig.com',
#  'nsnews.com',
#  'webindia123.com',
#  'ufosightingsdaily.com',
#  'idigitaltimes.com',
#  'goodgearguide.com.au',
#  'typepad.com',
#  'coastreporter.net',
#  'nypost.com',
#  'techworm.net',
#  'gsmarena.com',
#  'suntimes.com',
#  'dailykos.com',
#  'idg.com.au',
#  'ottawacitizen.com',
#  'businesstimes.com.sg',
#  'ajc.com',
#  'ninemsn.com.au',
#  'timesunion.com',
#  'bt.com',
#  'kvor.com',
#  'postandcourier.com',
#  'technewstoday.com',
#  'ammoland.com',
#  'techspot.com',
#  'nerdist.com',
#  'post-gazette.com',
#  'americablog.com',
#  'idahostatejournal.com',
#  'qz.com',
#  'tech.co',
#  'technobuffalo.com',
#  'blogher.com',
#  'lethbridgeherald.com',
#  'huffingtonpost.ca',
#  'brecorder.com',
#  'zerohedge.com',
#  'wordpress.com',
#  'moddb.com',
#  'irishmirror.ie',
#  'pocket-lint.com',
#  'bendbulletin.com',
#  'thespec.com',
#  'krmg.com',
#  'missourinews-online.com',
#  'techweekeurope.co.uk',
#  'hpuy.com',
#  'free-press-release-center.info',
#  'dslreports.com',
#  'panarmenian.net',
#  'craveonline.com',
#  'itproportal.com',
#  'pcworld.co.nz',
#  'news-sentinel.com',
#  'rockpapershotgun.com',
#  'kinston.com',
#  'miamiherald.com',
#  'prisonplanet.com',
#  'krcrtv.com',
#  'ctvnews.ca',
#  'readingeagle.com',
#  'sacbee.com',
#  'sandiegouniontribune.com',
#  '630wpro.com',
#  'yorktonnews.com',
#  'siliconvalley.com',
#  'abc6onyourside.com',
#  'dailydot.com',
#  'investopedia.com',
#  'thetimes.co.uk',
#  'cmo.com.au',
#  'learnbonds.com',
#  'newsviewsnreviews.com',
#  'techrepublic.com',
#  'jdsupra.com',
#  'wdbj7.com',
#  'sunshinecoastdaily.com.au',
#  'arabnews.com',
#  'tomsguide.com',
#  'webpronews.com',
#  'lifehacker.co.uk',
#  'cepro.com',
#  '9to5mac.com',
#  'montrealgazette.com',
#  'searchenginejournal.com',
#  'adage.com',
#  'digitalspy.com',
#  'siasat.com',
#  'insidetoronto.com',
#  'ukauthority.com',
#  'kansascity.com',
#  'nextbigfuture.com',
#  'fonearena.com',
#  'busbyway.com',
#  'news965.com',
#  'solonews.net',
#  'e27.co',
#  'jewocity.com',
#  'wtma.com',
#  'dailyamerican.com',
#  'her.ie',
#  'military-technologies.net',
#  'abruzzo.tv',
#  'bdtonline.com',
#  'thetechportal.in',
#  'ibnlive.com',
#  'prwire.com.au',
#  'oregonlive.com',
#  'infotel.ca',
#  'gurufocus.com',
#  'campaignlive.co.uk',
#  'gamerant.com',
#  'shorelinemedia.net',
#  'krdo.com',
#  'mykawartha.com',
#  'mississauga.com',
#  'santamariatimes.com',
#  'sakshipost.com',
#  'timesofisrael.com',
#  'thefrontierpost.com',
#  'unitedwithisrael.org',
#  'philly.com',
#  'thepeninsulaqatar.com',
#  'thejournal.ie',
#  'westfieldtimes.com',
#  'osnews.com',
#  'mytechbits.com',
#  'thefiscaltimes.com',
#  'freep.com',
#  'tdm.com',
#  'wsfa.com',
#  'whistlerquestion.com',
#  'telegram.com',
#  'tvgrapevine.com',
#  'gizbot.com',
#  'heraldscotland.com',
#  'cityam.com',
#  'pymnts.com',
#  'kpic.com',
#  'lifescript.com',
#  'ourwindsor.ca',
#  'iafrica.com',
#  'idownloadblog.com',
#  'itpro.co.uk',
#  'thehill.com',
#  'todayonline.com',
#  'vcpost.com',
#  'abcnews.com',
#  'latinpost.com',
#  '660news.com',
#  'consumerelectronicsnet.com',
#  'belfasttelegraph.co.uk',
#  'accesswdun.com',
#  'abc.net.au',
#  'fox23.com',
#  'mysanantonio.com',
#  'journal-news.com',
#  'forexnews.com',
#  'androidguys.com',
#  'wben.com',
#  'digit.in',
#  'heraldtribune.com',
#  'tickerreport.com',
#  'trust.org',
#  'popherald.com',
#  'news8000.com',
#  'washingtonexaminer.com',
#  'dailyrecord.co.uk',
#  'ktvn.com',
#  'news24.com',
#  'cso.com.au',
#  'geeky-gadgets.com',
#  'concordmonitor.com',
#  'hawaiinewsnow.com',
#  'valleymorningstar.com',
#  'dealnews.com',
#  'waff.com',
#  'kkoh.com',
#  'thespaceshow.com',
#  'nysepost.com',
#  'columbustelegram.com',
#  'amazon.com',
#  'kawc.org',
#  'smallbiztrends.com',
#  'register-herald.com',
#  'durhamregion.com',
#  'thaivisa.com',
#  'wsbtv.com',
#  'metro.us',
#  'computerworld.com.au',
#  'tampabay.com',
#  'legalinsurrection.com',
#  'mykeystrokes.com',
#  'shorelinetimes.com',
#  'geeksofdoom.com',
#  'investorplace.com',
#  'broadcastingcable.com',
#  'torontosun.com',
#  'people.com',
#  'news957.com',
#  'tdn.com',
#  'localnews8.com',
#  'innovationtoronto.com',
#  'androidandme.com',
#  'simcoe.com',
#  'abc17news.com',
#  'bramptonguardian.com',
#  'lasvegassun.com',
#  'netindia123.com',
#  'mychamplainvalley.com',
#  'channel3000.com',
#  'villagesoup.com',
#  'tweeddailynews.com.au',
#  'rapidcityjournal.com',
#  'newrepublic.com',
#  'yorkregion.com',
#  'ntnews.com.au',
#  'kxly.com',
#  'thenational.ae',
#  'theinquirer.net',
#  'wbrc.com',
#  'chippewa.com',
#  'mamamia.com.au',
#  'siliconrepublic.com',
#  'wxow.com',
#  'kswo.com',
#  'cmswire.com',
#  'newswest9.com',
#  'kxxv.com',
#  'chinadaily.com.cn',
#  'tjcnewspaper.com',
#  'ocregister.com',
#  'geekzone.co.nz',
#  'newstalk.com',
#  'japantoday.com',
#  '9news.com.au',
#  'indiedb.com',
#  'newser.com',
#  'nj1015.com',
#  'macmegasite.com',
#  'gosanangelo.com',
#  'newschannel20.com',
#  'govtech.com',
#  'nation.com.pk',
#  'phonedog.com',
#  'perezhilton.com',
#  'keprtv.com',
#  'boingboing.net',
#  'wcti12.com',
#  'maitlandmercury.com.au',
#  'chrisjonesgaming.net',
#  'kcra.com',
#  'kvia.com',
#  'kptv.com',
#  'cambridgetimes.ca',
#  'ianslive.in',
#  'biztekmojo.com',
#  'wfsb.com',
#  'streamdaily.tv',
#  'vrfocus.com',
#  'chroniclejournal.com',
#  'v3.co.uk',
#  'japantimes.co.jp',
#  'nairobimombasa.com',
#  'financialbuzz.com',
#  'financialpost.com',
#  'dailystar.co.uk',
#  'goupstate.com',
#  'theledger.com',
#  'charlotteobserver.com',
#  'themercury.com.au',
#  'onenewspage.com',
#  'chinatopix.com',
#  'actionnewsjax.com',
#  'townhall.com',
#  'thehindubusinessline.com',
#  'theet.com',
#  'wect.com',
#  'cio.com.au',
#  'ctrlhelp.com',
#  'kboi2.com',
#  'macdailynews.com',
#  'canada.com',
#  'hothardware.com',
#  'wsbradio.com',
#  'nme.com',
#  'emirates247.com',
#  'illawarramercury.com.au',
#  'newstalkkgvo.com',
#  'nola.com',
#  'opb.org',
#  'moneyandweb.eu',
#  'nbcmontana.com',
#  'channel4000.com',
#  'wcyb.com',
#  'manchestereveningnews.co.uk',
#  'tomshardware.com',
#  'idgconnect.com',
#  'springfieldnewssun.com',
#  'kplctv.com',
#  'mangalorean.com',
#  'koaa.com',
#  'psychologytoday.com',
#  'wired.co.uk',
#  'live5news.com',
#  'detroitnews.com',
#  'telecompaper.com',
#  'huffingtonpost.in',
#  'msnewsnow.com',
#  'ew.com',
#  'prnewswire.co.uk',
#  'krvn.com',
#  'theeagle.com',
#  '680news.com',
#  'hngn.com',
#  '570news.com',
#  'eteknix.com',
#  'dallasnews.com',
#  'foxla.com',
#  'sott.net',
#  'deseretnews.com',
#  'polygon.com',
#  'geelongadvertiser.com.au',
#  'niagarathisweek.com',
#  'klewtv.com',
#  'bakersfieldnow.com',
#  'komando.com',
#  'therakyatpost.com',
#  'searchenginewatch.com',
#  'kspr.com',
#  'yourstory.com',
#  'rocketnews24.com',
#  'nairaland.com',
#  'digitalmedianet.com',
#  'wwntradio.com',
#  'poststar.com',
#  'localsyr.com',
#  'statesman.com',
#  'iusbpreface.com',
#  'bdlive.co.za',
#  'care2.com',
#  'theinsidekorea.com',
#  'it-online.co.za',
#  'wistv.com',
#  'socialmediatoday.com',
#  'breaking.tcm.ie',
#  'worldne.ws',
#  'wjcl.com',
#  'ksby.com',
#  'worldbank.org',
#  'wdam.com',
#  'wmbfnews.com',
#  'dagblog.com',
#  '10news.com',
#  '3dprint.com',
#  'vccircle.com',
#  'sbs.com.au',
#  'blueridgenow.com',
#  'kimatv.com',
#  '610kvnu.com',
#  'thefutoncritic.com',
#  'abqjournal.com',
#  'bordermail.com.au',
#  'tweaktown.com',
#  'wptv.com',
#  'trib.com',
#  'hackaday.com',
#  'bandt.com.au',
#  'ktar.com',
#  'comunicati.net',
#  'batemansbaypost.com.au',
#  'fresnobee.com',
#  'techone3.in',
#  'redding.com',
#  'newsobserver.com',
#  'wccftech.com',
#  'stockhouse.com',
#  'i4u.com',
#  'arkansasonline.com',
#  'stuff.tv',
#  'wbtw.com',
#  'conservativeread.com',
#  '1310news.com',
#  'rcrwireless.com',
#  'wtoc.com',
#  'deccanherald.com',
#  'wpxi.com',
#  'so-co-it.com',
#  'siliconbeat.com',
#  'moneymorning.com.au',
#  'newschannel10.com',
#  'expertreviews.co.uk',
#  'lex18.com',
#  'wondradio.com',
#  'chieftain.com',
#  'timeslive.co.za',
#  'eurekalert.org',
#  'fin24.com',
#  'npr.org',
#  'cinemablend.com',
#  'goodmenproject.com',
#  'romaniapress.com',
#  'yakimaherald.com',
#  'begadistrictnews.com.au',
#  'news1130.com',
#  'kingstonregion.com',
#  'cbs5az.com',
#  'kait8.com',
#  'sunraysiadaily.com.au',
#  'phillyvoice.com',
#  'brudirect.com',
#  'khq.com',
#  'mid-day.com',
#  'komonews.com',
#  'the-daily-news.net',
#  'firstshowing.net',
#  'dailyadvertiser.com.au',
#  'indiewire.com',
#  'weyburnthisweek.com',
#  'news3lv.com',
#  'journaltimes.com',
#  'windsorstar.com',
#  'ktuu.com',
#  'southcoastregister.com.au',
#  'kotatv.com',
#  'fitnhit.com',
#  'northumberlandnews.com',
#  'reviewtimes.com',
#  'escapistmagazine.com',
#  'jagran.com',
#  'list-online.com',
#  'registerguard.com',
#  'macworld.com',
#  'southernhighlandnews.com.au',
#  'dailyvoice.com',
#  'carlyleobserver.com',
#  'tristatehomepage.com',
#  'whio.com',
#  'kgw.com',
#  'webwire.com',
#  'everythinglubbock.com',
#  'wokv.com',
#  'businessfinancenews.com',
#  'fox30jax.com',
#  'pc-tablet.co.in',
#  '9to5google.com',
#  'dailyjournalonline.com',
#  'fox8live.com',
#  'acnnewswire.com',
#  'abcnewsradioonline.com',
#  'charismanews.com',
#  'wpsdlocal6.com',
#  'billsinsider.com',
#  'observer.com',
#  'rt.com',
#  'heavy.com',
#  'whdh.com',
#  'northjersey.com',
#  'centralmaine.com',
#  'wjactv.com',
#  'naroomanewsonline.com.au',
#  'indiatvnews.com',
#  'wsmv.com',
#  'kticradio.com',
#  'gazettetimes.com',
#  'theindianrepublic.com',
#  'mumbrella.com.au',
#  'reviewjournal.com',
#  'kctv5.com',
#  'lillooetnews.net',
#  'news.gc.ca',
#  'westernadvocate.com.au',
#  'christianpost.com',
#  'insidebelleville.com',
#  'citizen.co.za',
#  'travelpulse.com',
#  'augusta.com',
#  'wtvm.com',
#  'wareable.com',
#  'gcabc.ca',
#  'wtsp.com',
#  'ksla.com',
#  'medianama.com',
#  'prweek.com',
#  'capradio.org',
#  'marketingmagazine.co.uk',
#  'kmir.com',
#  'capitalfm.co.ke',
#  'lifehacker.co.in',
#  'organic-food-tips.com',
#  'lbc.co.uk',
#  'mytwintiers.com',
#  'kitguru.net',
#  'muscatinejournal.com',
#  'enca.com',
#  'fusion.net',
#  'codeproject.com',
#  'knowyourmobile.com',
#  'networksasia.net',
#  'kiiitv.com',
#  'patheos.com',
#  'aaj.tv',
#  'walesonline.co.uk',
#  'timesonline.com',
#  'tucsonnewsnow.com',
#  'myrtlebeachonline.com',
#  'ky3.com',
#  'northwestgeorgianews.com',
#  'investcorrectly.com',
#  'nationmultimedia.com',
#  'tuscaloosanews.com',
#  'newsnation.in',
#  'keyetv.com',
#  'wsoctv.com',
#  'sky.com',
#  'ourmidland.com',
#  'iphonehacks.com',
#  'jalopnik.com',
#  'newsnet5.com',
#  'mediaite.com',
#  'ottawacommunitynews.com',
#  'abc2news.com',
#  'thehulltruth.com',
#  'findlaw.com',
#  'kjrh.com',
#  'android.gs',
#  'abc7ny.com',
#  'cumberlink.com',
#  'masslive.com',
#  'brantnews.com',
#  'wbur.org',
#  'newsradioklbj.com',
#  'mobilitytechzone.com',
#  'yourhoustonnews.com',
#  'fredericknewspost.com',
#  '411mania.com',
#  'mycentraloregon.com',
#  'katu.com',
#  'musictimes.com',
#  'winbeta.org',
#  'cosmopolitan.com',
#  'liliputing.com',
#  'humboldtjournal.ca',
#  ...]

# %%
most_TONE = TONE[TONE.agency.isin(sel_companies)] # 1 FILTER

# %%
GCAM_most = ['c18.59', 'c18.60', 'c18.61', 'c18.63', 'c18.154','c18.286', 'c18.287', 'c18.288']

GCAM = ['c18.59', 'c18.60', 'c18.61', 'c18.63', 'c18.154','c18.286', 'c18.287', 'c18.288', 'c1.2', 'c2.45',
        'c2.58', 'c4.1', 'c4.16', 'c9.853', 'c16.47', 'c16.60', 'c18.36',
        'c18.42', 'c18.47', 'c18.53', 'c18.54', 'c18.62', 'c18.178',
        'c18.187', 'c18.188', 'c18.189', 'c18.213', 'c18.214', 'c18.215', 'c18.218',
       'c18.219', 'c18.223', 'c18.225', 'c18.246', 'c18.247', 'c18.248', 'c18.258', 
        'c18.272', 'c18.279', 'c18.280', 'c18.289', 'c18.290', 'c18.292', 'c18.293', 'c18.294', 'c18.307', 'c18.332', 
       'c18.335']

# %%
fin = list()
for el in most_TONE.words:
    dec = False
    for tp in GCAM_most:
        if tp in el:
            dec = True
    fin.append(dec)
most_TONE['financial'] = fin
# Out:
# /home/ostapkharysh/.local/lib/python3.5/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#most_TONE = most_TONE[most_TONE.financial == True]
#print(most_TONE.agency.unique())
most_TONE.head()
# Out:
#                  date      tone  positive  negative  polarity  activ_den  \
# 1 2016-01-01 00:15:00 -1.758014  2.068252  3.826267  5.894519  24.819028
# 2 2016-01-01 00:15:00  0.973236  2.433090  1.459854  3.892944  13.381995
# 3 2016-01-01 00:15:00 -2.694136  2.535658  5.229794  7.765452  20.998415
# 4 2016-01-01 00:15:00 -2.764977  2.534562  5.299539  7.834101  21.006144
# 5 2016-01-01 00:15:00  6.430155  7.982262  1.552106  9.534368  22.912047
#
#    self_den                                             source  \
# 1  0.310238  http://www.nzherald.co.nz/opinion/news/article...
# 2  1.459854  http://www.fltimes.com/raw-explosion-in-dubai-...
# 3  1.584786  http://www.gizmodo.com.au/2016/01/las-gas-leak...
# 4  1.036866  http://www.theunitedvoiceofamerica.com/mccain-...
# 5  1.626016        http://comicsalliance.com/tags/braden-lamb/
#
#                         agency  \
# 1               nzherald.co.nz
# 2                  fltimes.com
# 3               gizmodo.com.au
# 4  theunitedvoiceofamerica.com
# 5           comicsalliance.com
#
#                                                words  price  financial
# 1  wc:894,c1.2:4,c1.3:2,c12.1:74,c12.10:112,c12.1...    NaN       True
# 2  wc:313,c12.1:14,c12.10:50,c12.12:10,c12.13:16,...    NaN      False
# 3  wc:1158,c1.2:3,c1.3:15,c12.1:61,c12.10:117,c12...    NaN      False
# 4  wc:2341,c1.1:1,c1.3:4,c1.4:5,c12.1:191,c12.10:...    NaN      False
# 5  wc:1193,c1.1:2,c1.4:2,c12.1:101,c12.10:121,c12...    NaN      False

# %%
#most_TONE = most_TONE[most_TONE.price.notnull()]
#del most_TONE['date']

# %%
most_TONE = most_TONE.reset_index(drop=True)
most_TONE.head()
# Out:
#                  date      tone  positive  negative  polarity  activ_den  \
# 0 2016-01-01 00:15:00 -1.758014  2.068252  3.826267  5.894519  24.819028
# 1 2016-01-01 00:15:00  0.973236  2.433090  1.459854  3.892944  13.381995
# 2 2016-01-01 00:15:00 -2.694136  2.535658  5.229794  7.765452  20.998415
# 3 2016-01-01 00:15:00 -2.764977  2.534562  5.299539  7.834101  21.006144
# 4 2016-01-01 00:15:00  6.430155  7.982262  1.552106  9.534368  22.912047
#
#    self_den                                             source  \
# 0  0.310238  http://www.nzherald.co.nz/opinion/news/article...
# 1  1.459854  http://www.fltimes.com/raw-explosion-in-dubai-...
# 2  1.584786  http://www.gizmodo.com.au/2016/01/las-gas-leak...
# 3  1.036866  http://www.theunitedvoiceofamerica.com/mccain-...
# 4  1.626016        http://comicsalliance.com/tags/braden-lamb/
#
#                         agency  \
# 0               nzherald.co.nz
# 1                  fltimes.com
# 2               gizmodo.com.au
# 3  theunitedvoiceofamerica.com
# 4           comicsalliance.com
#
#                                                words  price  financial
# 0  wc:894,c1.2:4,c1.3:2,c12.1:74,c12.10:112,c12.1...    NaN       True
# 1  wc:313,c12.1:14,c12.10:50,c12.12:10,c12.13:16,...    NaN      False
# 2  wc:1158,c1.2:3,c1.3:15,c12.1:61,c12.10:117,c12...    NaN      False
# 3  wc:2341,c1.1:1,c1.3:4,c1.4:5,c12.1:191,c12.10:...    NaN      False
# 4  wc:1193,c1.1:2,c1.4:2,c12.1:101,c12.10:121,c12...    NaN      False

# %%
print(len(most_TONE))
most_TONE[most_TONE.financial==True].corr()
# Out:
# 170975
#                tone  positive  negative  polarity  activ_den  self_den  \
# tone       1.000000  0.621279 -0.849334 -0.377833  -0.083888  0.179986
# positive   0.621279  1.000000 -0.114051  0.490765   0.019836  0.236710
# negative  -0.849334 -0.114051  1.000000  0.809634   0.119720 -0.068739
# polarity  -0.377833  0.490765  0.809634  1.000000   0.116715  0.079561
# activ_den -0.083888  0.019836  0.119720  0.116715   1.000000  0.274114
# self_den   0.179986  0.236710 -0.068739  0.079561   0.274114  1.000000
# price      0.050704  0.004842 -0.064298 -0.054629   0.058818  0.004590
# financial       NaN       NaN       NaN       NaN        NaN       NaN
#
#               price  financial
# tone       0.050704        NaN
# positive   0.004842        NaN
# negative  -0.064298        NaN
# polarity  -0.054629        NaN
# activ_den  0.058818        NaN
# self_den   0.004590        NaN
# price      1.000000        NaN
# financial       NaN        NaN

# %%
print(len(most_TONE[['tone']]))
print(len(most_TONE[most_TONE.financial==True][['tone']]))

most_TONE[['tone']].plot()
most_TONE[most_TONE.financial==True][['tone']].plot()
# Out:
# 170975
# 16769

# %%
print(len(ton_ag))
ton_ag[:10]
# Out:
# 10716
# [('yahoo.com', 3947),
#  ('haberajans.net', 1472),
#  ('american-reporter.com', 1464),
#  ('toptechnews.com', 934),
#  ('marketwatch.com', 922),
#  ('vtdigger.org', 831),
#  ('4-traders.com', 777),
#  ('fltimes.com', 736),
#  ('gizmodo.com.au', 696),
#  ('blogspot.com', 674)]

# %% [markdown]
# ### Page Rank Prioritization

# %%
rank = pd.read_csv('/home/ostapkharysh/Documents/bt_data/news_rank/agency_rank.csv')

# %%
rank.head()
# Out:
#    harmonicc_pos  harmonicc_val  pr_pos    pr_val      host_rev  n_hosts
# 0              1     27203288.0       2  0.012818  facebook.com     6707
# 1              3     25533108.0       3  0.010690    google.com     3331
# 2              4     24267906.0       4  0.007625   twitter.com     1179
# 3              5     24001384.0       5  0.006755   youtube.com     3032
# 4              9     20954100.0      11  0.003053  linkedin.com      665

# %%
del rank
